# %%
import pandas as pd
import numpy  as np
import datetime as dt
import os

# %%
class Game:
    def __init__(self, date, game, players, winner):
        self.filepath = "out/"
        if not os.path.exists(self.filepath):
            os.makedirs(self.filepath)
        self.data = None
        self.filename = "database.csv"
        self.full_filename = os.path.join(self.filepath, self.filename)
        
        self._id = self.__load_id()
        self.date = date#dt.datetime.strptime(date, '%d/%m/%y')
        self.game = game
        self.players = players
        self.winner = winner
        
        self.__initialize()
    
    def __load_id(self):
        file_id = os.path.join(self.filepath, "._id.log")

        if not os.path.exists(file_id):
            with open(file_id, "w") as file:
                _id = 1
                file.write(str(_id))
        else:
            with open(file_id, "r") as file:
                _id = int(file.read())+1
            
            with open(file_id, "w") as file:
                file.write(str(_id))
                
        return _id
            
    def __initialize(self):
        row = pd.DataFrame(
                dict(
                gid=self._id,
                date=self.date,
                game=self.game,
                players=self.players,
                winner=self.winner
            )
        )
        if os.path.exists(self.full_filename):
            self.data = pd.read_csv(self.full_filename)
        else:
            self.data = pd.DataFrame()
        self.data = self.data.append(row) 
        
    def save(self):       
        self.data.to_csv(self.full_filename, index=None)

# %%
games = [
    dict(date="26/09/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Isela"),
    dict(date="26/09/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Isela"),
    dict(date="26/09/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="26/09/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="26/09/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="26/09/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Isela"),
    
    dict(date="26/09/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Isela"),
    dict(date="26/09/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="26/09/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="26/09/20", game="Munchkin", players=["David", "Arturo", "Isela"], winner="Isela"),
    dict(date="26/09/20", game="Munchkin", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="26/09/20", game="Munchkin", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="26/09/20", game="Encantados", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="26/09/20", game="Encantados", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="26/09/20", game="Saboteur", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="26/09/20", game="Saboteur", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="09/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="09/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="09/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="09/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="09/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/10/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="Isela"),
    
    dict(date="09/10/20", game="Encantados", players=["Adriano", "David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"], winner="David"),
    dict(date="09/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"], winner="David"),
    
    dict(date="09/10/20", game="Ninja Camp", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    dict(date="09/10/20", game="Bohnanza", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/10/20", game="Saboteur", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/10/20", game="Munchkin", players=["David", "Adriano", "Arturo", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="10/10/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="10/10/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="10/10/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="10/10/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="10/10/20", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="10/10/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="10/10/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="10/10/20", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="10/10/20", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="15/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="15/10/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="Isela"),
    
    dict(date="15/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="16/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Isela"),
    dict(date="16/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="16/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="16/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="16/10/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="16/10/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="16/10/20", game="Ninja Camp", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="16/10/20", game="Ninja Camp", players=["David", "Arturo", "Isela"], winner="Arturo"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [   
    dict(date="17/10/20", game="Ninja Camp", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="17/10/20", game="Ninja Camp", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="17/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="17/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    dict(date="17/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="17/10/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [   
    dict(date="17/10/20", game="Ninja Camp", players=["David", "Adriano", "Arturo", "Isela"],winner="Adriano"),
    dict(date="17/10/20", game="Ninja Camp", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    
    dict(date="17/10/20", game="Port Royal", players=["David", "Adriano", "Arturo", "Isela"],winner="Adriano"),
    dict(date="17/10/20", game="Port Royal", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    dict(date="17/10/20", game="Port Royal", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    dict(date="17/10/20", game="Port Royal", players=["David", "Adriano", "Arturo", "Isela"],winner="David"),
    
    dict(date="17/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"],winner="Adriano"),
    dict(date="17/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    dict(date="17/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    dict(date="17/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"],winner="Isela"),
    dict(date="17/10/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"],winner="Isela"),
    
    dict(date="17/10/20", game="Bohnanza", players=["David", "Adriano", "Arturo", "Isela"],winner="Isela"),
    dict(date="17/10/20", game="Bohnanza", players=["David", "Adriano", "Arturo", "Isela"],winner="Isela"),
    
    dict(date="17/10/20", game="Encantados", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    
    dict(date="17/10/20", game="Saboteur", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    
    dict(date="17/10/20", game="Munchkin", players=["David", "Adriano", "Arturo", "Isela"],winner="Arturo"),
    dict(date="17/10/20", game="Munchkin", players=["David", "Adriano", "Arturo", "Isela"],winner="Isela"),   
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="23/10/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="23/10/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    
    dict(date="23/10/20", game="Oh my goods", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="23/10/20", game="Oh my goods", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="23/10/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"],winner="Arturo"),
    dict(date="23/10/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"],winner="Arturo"),
    
    dict(date="23/10/20", game="Encantados", players=["Arturo", "Adriano", "Isela"],winner="Isela"),
    dict(date="23/10/20", game="Encantados", players=["Arturo", "Adriano", "Isela"],winner="Isela"),
    dict(date="23/10/20", game="Encantados", players=["Arturo", "Adriano", "Isela"],winner="Arturo"),
    dict(date="23/10/20", game="Encantados", players=["Arturo", "Adriano", "Isela"],winner="Adriano"),
    
    dict(date="23/10/20", game="Kariba", players=["Arturo", "Adriano", "Isela"],winner="Adriano"),
    dict(date="23/10/20", game="Kariba", players=["Arturo", "Adriano", "Isela"],winner="Isela"),
    
    dict(date="23/10/20", game="Bohnanza", players=["Arturo", "Adriano", "Isela"],winner="Isela"),

]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="24/10/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="24/10/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="24/10/20", game="Oh my goods", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="24/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="24/10/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="24/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="24/10/20", game="Port Royal", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="24/10/20", game="Ninja Camp", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="24/10/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="25/10/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="25/10/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="Isela"),
    
    dict(date="25/10/20", game="Oh my goods", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="25/10/20", game="Encantados", players=["David", "Arturo", "Isela"],winner="Isela"),
    dict(date="25/10/20", game="Encantados", players=["David", "Arturo", "Isela"],winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="09/11/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="09/11/20", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="09/11/20", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="09/11/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="09/11/20", game="Oh my goods", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="09/11/20", game="Kariba", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="09/11/20", game="Kariba", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="09/11/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Kariba", players=["David", "Arturo", "Isela"], winner="David"),
    
    dict(date="09/11/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Arturo"),
    dict(date="09/11/20", game="Lhama", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/11/20", game="Bohnanza", players=["David", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="09/11/20", game="Encantados", players=["David", "Arturo", "Isela"],winner="David"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="11/11/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    dict(date="11/11/20", game="Lhama", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="11/11/20", game="Bohnanza", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="11/11/20", game="Kariba", players=["David", "Adriano", "Arturo", "Isela"], winner="David"),
    dict(date="11/11/20", game="Kariba", players=["David", "Adriano", "Arturo", "Isela"], winner="Isela"),
    
    dict(date="11/11/20", game="Ninja Camp", players=["David", "Adriano", "Arturo", "Isela"], winner="Adriano"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="11/11/20", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="11/11/20", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="11/11/20", game="Kariba", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="11/11/20", game="Kariba", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="11/11/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="13/11/20", game="Encantados", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    dict(date="13/11/20", game="Encantados", players=["David", "Adriano", "Arturo", "Isela"], winner="David"),
    
    dict(date="13/11/20", game="Kariba", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    dict(date="13/11/20", game="Kariba", players=["David", "Adriano", "Arturo", "Isela"], winner="David"),
    
    dict(date="13/11/20", game="Port Royal", players=["David", "Adriano", "Arturo", "Isela"], winner="Arturo"),
    
    dict(date="13/11/20", game="Bohnanza", players=["David", "Adriano", "Arturo", "Isela"], winner="Isela"),
    
    dict(date="13/11/20", game="Munchkin", players=["David", "Adriano", "Arturo", "Isela"], winner="Isela"),
    dict(date="13/11/20", game="Munchkin", players=["David", "Adriano", "Arturo", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="13/12/20", game="Kingdomino", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="13/12/20", game="Kingdomino", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="13/12/20", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="13/12/20", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="13/12/20", game="Port Royal", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),    
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="24/12/20", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="24/12/20", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="24/12/20", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="26/12/20", game="Kingdomino", players=["Arturo", "Adriano", "David"], winner="Adriano"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="26/12/20", game="Ninja Camp", players=["Arturo", "Adriano", "David", "Isela"], winner="Adriano"),
    
    dict(date="26/12/20", game="Bohnanza", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="31/12/20", game="Kariba", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    dict(date="31/12/20", game="Kariba", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="31/12/20", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="Adriano"),
    dict(date="31/12/20", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
    
    dict(date="31/12/20", game="Port Royal", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="31/12/20", game="Kingdomino", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="31/12/20", game="Ninja Camp", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="31/12/20", game="Bohnanza", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
    
    dict(date="31/12/20", game="Encantados", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
    
    dict(date="31/12/20", game="Oh my goods", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
]

for game in games:
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="01/01/21", game="Munchkin", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="01/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="01/01/21", game="Kingdomino", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="03/01/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="03/01/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="03/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="03/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="03/01/21", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="09/01/21", game="Misty", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/01/21", game="Misty", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/01/21", game="Misty", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="09/01/21", game="Misty", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="09/01/21", game="Bode of War", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/01/21", game="Bode of War", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/01/21", game="Bode of War", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="09/01/21", game="Bode of War", players=["Arturo", "Adriano", "Isela"], winner="Isela"),  
    
    dict(date="09/01/21", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    
    dict(date="09/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="10/01/21", game="Misty", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="10/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="10/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="15/01/21", game="Encantados", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="15/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="15/01/21", game="Misty", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="15/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="15/01/21", game="Bohnanza", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="15/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="16/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="Adriano"),
    dict(date="16/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="16/01/21", game="Misty", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="16/01/21", game="Kingdomino", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="16/01/21", game="Oh my goods", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
    
    dict(date="16/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="16/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="16/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="17/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    dict(date="17/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="Adriano"),
    
    dict(date="17/01/21", game="Ninja Camp", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="17/01/21", game="Cartografos", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="18/01/21", game="Cartografos", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="18/01/21", game="Cartografos", players=["Arturo", "David", "Isela"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="19/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="19/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="20/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="20/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Isela"),
    dict(date="20/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Isela"),
    dict(date="20/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="21/01/21", game="Bohnanza", players=["Arturo", "David", "Isela"], winner="Arturo"),
    
    dict(date="21/01/21", game="Bode of War", players=["Arturo", "David", "Isela"], winner="David"),
    dict(date="21/01/21", game="Bode of War", players=["Arturo", "David", "Isela"], winner="David"),
    dict(date="21/01/21", game="Bode of War", players=["Arturo", "David", "Isela"], winner="Isela"),
    
    dict(date="21/01/21", game="Kingdomino", players=["Arturo", "David", "Isela"], winner="Isela"),
    dict(date="21/01/21", game="Kingdomino", players=["Arturo", "David", "Isela"], winner="Isela"),
    
    dict(date="21/01/21", game="Cartografos", players=["Arturo", "David", "Isela"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="22/01/21", game="Munchkin", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="22/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    dict(date="22/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    dict(date="22/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
    dict(date="22/01/21", game="Bode of War", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
    
    dict(date="22/01/21", game="Misty", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="22/01/21", game="Encantados", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    dict(date="22/01/21", game="Encantados", players=["Arturo", "Adriano", "David", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="Arturo"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="David"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="David"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "David", "Isela"], winner="David"),
    
    dict(date="24/01/21", game="Bode of War", players=["Arturo", "Adriano", "David"], winner="David"),
    dict(date="24/01/21", game="Bode of War", players=["Arturo", "Adriano", "David"], winner="David"),
    dict(date="24/01/21", game="Bode of War", players=["Arturo", "Adriano", "David"], winner="David"),
    dict(date="24/01/21", game="Bode of War", players=["Arturo", "Adriano", "David"], winner="Adriano"),
    dict(date="24/01/21", game="Bode of War", players=["Arturo", "Adriano", "David"], winner="Adriano"),
    dict(date="24/01/21", game="Bode of War", players=["Arturo", "Adriano", "David"], winner="Adriano"),
    
    dict(date="24/01/21", game="Ninja Camp", players=["Arturo", "Adriano", "David"], winner="Adriano"),
    dict(date="24/01/21", game="Ninja Camp", players=["Arturo", "Adriano", "David"], winner="David"),
    
    dict(date="24/01/21", game="Oh my goods", players=["Arturo", "Adriano", "David", "Isela"], winner="Adriano"),
    
    dict(date="24/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="24/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    
    dict(date="24/01/21", game="Misty", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    
    dict(date="24/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="Arturo"),
    dict(date="24/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    dict(date="24/01/21", game="Lhama", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
    
    dict(date="24/01/21", game="Bohnanza", players=["Arturo", "Adriano", "David", "Isela"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="30/01/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="02/02/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="02/02/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="02/02/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="02/02/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="09/02/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"), 
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="17/03/21", game="Encantados", players=["Adriano", "David", "Isela"], winner="Isela"), 
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="21/03/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "George"], winner="George"), 
    
    dict(date="21/03/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "George"], winner="Arturo"), 
    
    dict(date="21/03/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "George"], winner="Arturo"), 
    
    dict(date="21/03/21", game="Misty", players=["Arturo", "Adriano", "Isela", "George"], winner="Isela"), 
    
    dict(date="21/03/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "George"], winner="Isela"), 
    
    dict(date="21/03/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "George"], winner="Arturo"), 
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="18/04/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"), 
    dict(date="18/04/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"), 
    
    dict(date="18/04/21", game="CIV", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    
    dict(date="18/04/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="18/04/21", game="Ninja Camp", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="18/04/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="18/04/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="18/04/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="18/04/21", game="Misty", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="18/04/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="18/04/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="02/05/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="02/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="02/05/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="02/05/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="07/05/21", game="Cartografos", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    
    dict(date="07/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="07/05/21", game="CIV", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="10/05/21", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="10/05/21", game="Lhama", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    
    dict(date="10/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="10/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="11/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="11/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    
    dict(date="11/05/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="13/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="13/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="13/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="14/05/21", game="Oh my goods", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="28/05/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="28/05/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="28/05/21", game="CIV", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="28/05/21", game="Misty", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    
    dict(date="28/05/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="28/05/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="18/06/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="18/06/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="18/06/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="18/06/21", game="Misty", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="18/06/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="18/06/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    dict(date="18/06/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="09/07/21", game="Kariba", players=["Adriano", "Isela", "David"], winner="Adriano"),
    dict(date="09/07/21", game="Kariba", players=["Adriano", "Isela", "David"], winner="David"),
    
    dict(date="09/07/21", game="Misty", players=["Adriano", "Isela", "David"], winner="Adriano"),
    dict(date="09/07/21", game="Misty", players=["Adriano", "Isela", "David"], winner="David"),
    
    dict(date="09/07/21", game="Encantados", players=["Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="09/07/21", game="Lhama", players=["Adriano", "Isela", "David"], winner="David"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="10/07/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="10/07/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="17/07/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    
    dict(date="17/07/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="17/07/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    dict(date="17/07/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="17/07/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    
    dict(date="17/07/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="17/07/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="17/07/21", game="Misty", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),
    
    dict(date="17/07/21", game="CIV", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    
    dict(date="17/07/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    
    dict(date="17/07/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %% [markdown]
# ## Actulizacion 01/03/22

# %%
games = [
    dict(date="24/07/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),

    dict(date="24/07/21", game="Misty", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),

    dict(date="24/07/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),

    dict(date="24/07/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),

    dict(date="24/07/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),

    dict(date="24/07/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="24/07/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="David"),

    dict(date="24/07/21", game="Ninja Camp", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="24/07/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="24/07/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="24/07/21", game="CIV", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="01/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="01/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="01/08/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),

    dict(date="01/08/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"), 

    dict(date="01/08/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="01/08/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
    dict(date="01/08/21", game="Bode of War", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),

    dict(date="01/08/21", game="CIV", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="01/08/21", game="Misty", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),

    dict(date="01/08/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),

    dict(date="01/08/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    dict(date="01/08/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    dict(date="01/08/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
    
    dict(date="01/08/21", game="Ninja Camp", players=["Arturo", "Adriano", "Isela", "David"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="27/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="27/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="27/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="27/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="27/08/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),

    dict(date="27/08/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Arturo"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Adriano"),
    dict(date="04/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela"], winner="Isela"),

    dict(date="04/10/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
    dict(date="04/10/21", game="Kingdomino", players=["Arturo", "Adriano", "Isela"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="25/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="25/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="25/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Arturo"),
    dict(date="25/10/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "David"], winner="Adriano"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="25/12/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "George"], winner="Adriano"),
    dict(date="25/12/21", game="Port Royal", players=["Arturo", "Adriano", "Isela", "George"], winner="Adriano"),

    dict(date="25/12/21", game="Bohnanza", players=["Arturo", "Adriano", "Isela", "George"], winner="Adriano"),

    dict(date="25/12/21", game="Misty", players=["Arturo", "Adriano", "Isela", "George"], winner="Arturo"),

    dict(date="25/12/21", game="Kariba", players=["Arturo", "Adriano", "Isela", "George"], winner="Arturo"),

    dict(date="25/12/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "George"], winner="Arturo"),
    dict(date="25/12/21", game="Encantados", players=["Arturo", "Adriano", "Isela", "George"], winner="George"),

    dict(date="25/12/21", game="Lhama", players=["Arturo", "Adriano", "Isela", "George"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()

# %%
games = [
    dict(date="01/01/22", game="Kingdomino", players=["Arturo", "Adriano", "Isela", "George"], winner="George"),

    dict(date="01/01/22", game="Encantados", players=["Arturo", "Adriano", "Isela", "George"], winner="Isela"),
]

for game in games: 
    g = Game(**game)
    g.save()
